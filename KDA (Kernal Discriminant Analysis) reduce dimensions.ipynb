# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# %%
# plot original Iris data

plt.figure (2, figsize = (6,5))
colors = ['turquoise','blue','red']
for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(X[y==i, 0], X[y==i, 1], alpha =.8, color = color, label = target_name)
plt.legend(loc = 'best', shadow = False, scatterpoints = 1)
plt.title('Original data')
plt.xlabel('Sepal length')
plt.ylabel ('Sepal width')
plt.show()
# Out:
# Text(0.5, 1.0, 'Original data')
# Text(0.5, 0, 'Sepal length')
# Text(0, 0.5, 'Sepal width')

# %%
#LDA applies Iris data
lda = LinearDiscriminantAnalysis(n_components = 2)
X_r2 = lda.fit(X,y).transform(X)

plt.figure(2,figsize=(6,5))
colors = ['turquoise','blue','red']
for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(X_r2[y==i, 0], X[y==i, 1], alpha =.8, color = color, label = target_name)
plt.legend(loc = 'best', shadow = False, scatterpoints = 1)
plt.title('LDA data')
plt.show()
# Out:
# Text(0.5, 1.0, 'LDA data')

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
tsne_results = tsne.fit_transform(X,y)

# %%
plt.figure(3,figsize=(6,5))
colors = ['turquoise','blue','red']
for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(tsne_results[y==i, 0], X[y==i, 1], alpha =.8, color = color, label = target_name)
plt.legend(loc = 'best', shadow = False, scatterpoints = 1)
plt.title('LDA data')
plt.show()
# Out:
# Text(0.5, 1.0, 'LDA data')

# %%
from sklearn.base import BaseEstimator, ClassifierMixin, TransformerMixin
kda = skkda.base.KernelDiscriminantAnalysis().fit(X,y).transform(X)

plt.figure(4,figsize=(6,5))
colors = ['turquoise','blue','red']
for color, i, target_name in zip(colors, [0,1,2], target_names):
    plt.scatter(kda[y==i, 0], X[y==i, 1], alpha =.8, color = color, label = target_name)
plt.legend(loc = 'best', shadow = False, scatterpoints = 1)
plt.title('KDA data')
plt.show()
# Out:
# Text(0.5, 1.0, 'KDA data')
